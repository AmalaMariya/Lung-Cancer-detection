# %% [markdown]
# LOADING THE DATASET

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\amala\Downloads\survey lung cancer.csv")
df
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        2              1
# 1        M   74        2               1        1              1
# 2        F   59        1               1        1              2
# 3        M   63        2               2        2              1
# 4        F   63        1               2        1              1
# ..     ...  ...      ...             ...      ...            ...
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
df.shape
# Out:
# (309, 16)

# %%
# Check the data types of each column
print(df.dtypes)
# Out:
# GENDER                   object
# AGE                       int64
# SMOKING                   int64
# YELLOW_FINGERS            int64
# ANXIETY                   int64
# PEER_PRESSURE             int64
# CHRONIC DISEASE           int64
# FATIGUE                   int64
# ALLERGY                   int64
# WHEEZING                  int64
# ALCOHOL CONSUMING         int64
# COUGHING                  int64
# SHORTNESS OF BREATH       int64
# SWALLOWING DIFFICULTY     int64
# CHEST PAIN                int64
# LUNG_CANCER              object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 309 non-null    object
#  1   AGE                    309 non-null    int64
#  2   SMOKING                309 non-null    int64
#  3   YELLOW_FINGERS         309 non-null    int64
#  4   ANXIETY                309 non-null    int64
#  5   PEER_PRESSURE          309 non-null    int64
#  6   CHRONIC DISEASE        309 non-null    int64
#  7   FATIGUE                309 non-null    int64
#  8   ALLERGY                309 non-null    int64
#  9   WHEEZING               309 non-null    int64
#  10  ALCOHOL CONSUMING      309 non-null    int64
#  11  COUGHING               309 non-null    int64
#  12  SHORTNESS OF BREATH    309 non-null    int64
#  13  SWALLOWING DIFFICULTY  309 non-null    int64
#  14  CHEST PAIN             309 non-null    int64
# ...

# %% [markdown]
# EXPLORATORY DATA ANALYSIS

# %% [markdown]
# 1. DOES SMOKING FREQUENCY CORRELATE WITH LUNG CANCER DIAGNOSIS?

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='SMOKING', hue='LUNG_CANCER', data=df,palette='husl')
plt.title('Smoking Frequency vs. Lung Cancer Diagnosis')
plt.xlabel('Smoking Frequency')
plt.ylabel('Count')
plt.legend(title='Lung Cancer')
plt.show()

# %% [markdown]
# 2. DO AGE AND LUNG CANCER DIAGNOSIS HAVE A SIGNIFICANT RELATIONSHIP?

# %%
sns.barplot(x='LUNG_CANCER', y='AGE', data=df,palette='coolwarm')
plt.title('Age vs. Lung Cancer Diagnosis')
plt.xlabel('Lung Cancer Diagnosis')
plt.ylabel('Age')
plt.show()
# Out:
# C:\Users\amala\AppData\Local\Temp\ipykernel_19880\2032260827.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='LUNG_CANCER', y='AGE', data=df,palette='coolwarm')

# %% [markdown]
# 3. ARE INDIVIDUALS WITH SYMPTOMS LIKE COUGHING AND CHEST PAIN MORE LIKELY TO BE DIAGNOSED WITH LUNG CANCER?

# %%
sns.catplot(x='COUGHING', hue='CHEST PAIN', col='LUNG_CANCER', data=df, kind='count', palette='viridis')
plt.subplots_adjust(top=0.9)
plt.suptitle('Coughing & Chest Pain vs. Lung Cancer Diagnosis')
plt.show()

# %% [markdown]
# 4. HOW DOES PEER PRESSURE AFFECT SMOKING FREQUENCY?

# %%
sns.boxplot(x='PEER_PRESSURE', y='SMOKING', data=df, palette='coolwarm')
plt.title('Peer Pressure vs. Smoking Frequency')
plt.xlabel('Peer Pressure Level')
plt.ylabel('Smoking Frequency')
plt.show()
# Out:
# C:\Users\amala\AppData\Local\Temp\ipykernel_19880\900473201.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='PEER_PRESSURE', y='SMOKING', data=df, palette='coolwarm')

# %% [markdown]
# 5. IS THERE AN INTERACTION BETWEEN CHRONIC DISEASE AND AGE IN LUNG CANCER DIAGNOSIS?

# %%
sns.scatterplot(x='AGE', y='CHRONIC DISEASE', hue='LUNG_CANCER', data=df, palette='Dark2')
plt.title('Chronic Disease and Age vs. Lung Cancer Diagnosis')
plt.xlabel('Age')
plt.ylabel('Chronic Disease')
plt.legend(title='Lung Cancer Diagnosis')
plt.show()

# %% [markdown]
# 6.  DOES CHEST PAIN CO-OCCUR WITH SHORTNESS OF BREATH IN LUNG CANCER PATIENTS?

# %%
sns.heatmap(
    pd.crosstab(df['CHEST PAIN'], df['SHORTNESS OF BREATH'], normalize='index'),
    annot=True, cmap='coolwarm', fmt='.2f'
)
plt.title('Chest Pain vs. Shortness of Breath Among Lung Cancer Patients')
plt.xlabel('Shortness of Breath Level')
plt.ylabel('Chest Pain Level')
plt.show()

# %% [markdown]
# 7.  DOES GENDER AFFECT THE INCIDENCE OF CHRONIC DISEASE IN LUNG CANCER CASES?

# %%
sns.countplot(x='GENDER', hue='CHRONIC DISEASE', data=df[df['LUNG_CANCER'] == 'YES'], palette='Set2')
plt.title('Gender vs. Chronic Disease in Lung Cancer Patients')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.legend(title='Chronic Disease Level')
plt.show()

# %% [markdown]
# 8. DO INDIVIDUALS WITH CHRONIC DISEASE EXPERIENCE HIGHER LEVELS OF ANXIETY?

# %%
sns.countplot(x='CHRONIC DISEASE', hue='ANXIETY', data=df, palette='cividis')
plt.title('Chronic Disease vs. Anxiety Levels')
plt.xlabel('Chronic Disease Presence')
plt.ylabel('Count of Anxiety Levels')
plt.legend(title='Anxiety Level')
plt.show()

# %% [markdown]
# 9. WHAT IS THE RELATIONSHIP BETWEEN SWALLOWING DIFFICULTY AND LUNG CANCER?

# %%
sns.countplot(x='SWALLOWING DIFFICULTY', hue='LUNG_CANCER', data=df, palette='icefire')
plt.title('Swallowing Difficulty vs. Lung Cancer Diagnosis')
plt.xlabel('Swallowing Difficulty Level')
plt.ylabel('Count')
plt.legend(title='Lung Cancer')
plt.show()

# %% [markdown]
# 10. DOES THE COMBINATION OF SHORTNESS OF BREATH AND COUGHING INDICATE A HIGHER LUNG CANCER RISK?

# %%
sns.catplot(x='SHORTNESS OF BREATH', hue='COUGHING', col='LUNG_CANCER', data=df, kind='count', palette='Spectral')
plt.subplots_adjust(top=0.9)
plt.suptitle('Shortness of Breath and Coughing in Lung Cancer Diagnosis')
plt.show()

# %% [markdown]
# ML

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import GridSearchCV
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# DATA PREPROCESSING

# %% [markdown]
# Handling missing data

# %%
# Check for missing values
df.isnull().sum()
# Out:
# GENDER                   0
# AGE                      0
# SMOKING                  0
# YELLOW_FINGERS           0
# ANXIETY                  0
# PEER_PRESSURE            0
# CHRONIC DISEASE          0
# FATIGUE                  0
# ALLERGY                  0
# WHEEZING                 0
# ALCOHOL CONSUMING        0
# COUGHING                 0
# SHORTNESS OF BREATH      0
# SWALLOWING DIFFICULTY    0
# CHEST PAIN               0
# LUNG_CANCER              0
# dtype: int64

# %% [markdown]
# Encode Categorical Data

# %%
#Convert categorical features like 'Gender' and 'Lung Cancer' target variable to numeric.

# Convert 'Gender' column to numeric (M = 0, F = 1)
df['GENDER'] = df['GENDER'].map({'M': 0, 'F': 1})

# Convert 'LUNG_CANCER' to binary (YES = 1, NO = 0)
df['LUNG_CANCER'] = df['LUNG_CANCER'].map({'YES': 1, 'NO': 0})

df.head()
# Out:
#    GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0       0   69        1               2        2              1
# 1       0   74        2               1        1              1
# 2       1   59        1               1        1              2
# 3       0   63        2               2        2              1
# 4       1   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  LUNG_CANCER
# ...

# %% [markdown]
# Feature Scaling

# %%
# Separate features (X) and target (y)
X = df.drop('LUNG_CANCER', axis=1)
y = df['LUNG_CANCER']

# Standardize the features using StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# SPLIT THE DATA INTO TRAINING AND TEST SETS

# %%
## Split the data into training and test sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

## Check the size of the splits
print(f"Training set size: {X_train.shape[0]}")
print(f"Test set size: {X_test.shape[0]}")
# Out:
# Training set size: 247
# Test set size: 62

# %% [markdown]
# MODEL SELECTION

# %% [markdown]
# Support vector machine(SVM)

# %%
# Initialize and train SVM Classifier
svm = SVC(random_state=42)
svm.fit(X_train, y_train)

# Make predictions on the test set
y_pred_svm = svm.predict(X_test)

# Evaluate the model
print("SVM Results:")
print(f"Accuracy: {accuracy_score(y_test, y_pred_svm):.2f}")
print(confusion_matrix(y_test, y_pred_svm))
print(classification_report(y_test, y_pred_svm))
# Out:
# SVM Results:
# Accuracy: 0.97
# [[ 1  1]
#  [ 1 59]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50         2
#            1       0.98      0.98      0.98        60
#
#     accuracy                           0.97        62
#    macro avg       0.74      0.74      0.74        62
# weighted avg       0.97      0.97      0.97        62

# %% [markdown]
# Random Forest

# %%
# Initialize and train Random Forest Classifier
rf = RandomForestClassifier(random_state=42)
rf.fit(X_train, y_train)

# Make predictions on the test set
y_pred_rf = rf.predict(X_test)

# Evaluate the model
print("Random Forest Results:")
print(f"Accuracy: {accuracy_score(y_test, y_pred_rf):.2f}")
print(confusion_matrix(y_test, y_pred_rf))
print(classification_report(y_test, y_pred_rf))
# Out:
# Random Forest Results:
# Accuracy: 0.97
# [[ 1  1]
#  [ 1 59]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50         2
#            1       0.98      0.98      0.98        60
#
#     accuracy                           0.97        62
#    macro avg       0.74      0.74      0.74        62
# weighted avg       0.97      0.97      0.97        62

# %% [markdown]
# Logistic Regression

# %%
# Initialize and train Logistic Regression model
log_reg = LogisticRegression()
log_reg.fit(X_train, y_train)

# Make predictions on the test set
y_pred_log_reg = log_reg.predict(X_test)

# Evaluate the model
print("Logistic Regression Results:")
print(f"Accuracy: {accuracy_score(y_test, y_pred_log_reg):.2f}")
print(confusion_matrix(y_test, y_pred_log_reg))
print(classification_report(y_test, y_pred_log_reg))
# Out:
# Logistic Regression Results:
# Accuracy: 0.97
# [[ 1  1]
#  [ 1 59]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50         2
#            1       0.98      0.98      0.98        60
#
#     accuracy                           0.97        62
#    macro avg       0.74      0.74      0.74        62
# weighted avg       0.97      0.97      0.97        62

# %% [markdown]
# MODEL EVALUATION

# %% [markdown]
# Here’s an example using Logistic Regression:

# %%
# Evaluation metrics for Logistic Regression
print(f"Accuracy of Logistic Regression: {accuracy_score(y_test, y_pred_log_reg):.2f}")
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_log_reg))
print("Classification Report:\n", classification_report(y_test, y_pred_log_reg))
# Out:
# Accuracy of Logistic Regression: 0.97
# Confusion Matrix:
#  [[ 1  1]
#  [ 1 59]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50         2
#            1       0.98      0.98      0.98        60
#
#     accuracy                           0.97        62
#    macro avg       0.74      0.74      0.74        62
# weighted avg       0.97      0.97      0.97        62

# %% [markdown]
# MODEL TUNING(HYPERPARAMETER TUNING USING GRIDSEARCHCV)

# %% [markdown]
# You can tune hyperparameters, for instance, for Random Forest:

# %%
# Define hyperparameter grid for Random Forest
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [10, 20, None],
    'min_samples_split': [2, 5, 10]
}

# Perform GridSearchCV
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=3, n_jobs=-1, verbose=2)
grid_search.fit(X_train, y_train)

# Best parameters from GridSearchCV
print("Best Parameters:", grid_search.best_params_)

# Use the best model found from GridSearchCV
best_rf = grid_search.best_estimator_

# Evaluate the best Random Forest model
y_pred_best_rf = best_rf.predict(X_test)
print("Best Random Forest Results:")
print(f"Accuracy: {accuracy_score(y_test, y_pred_best_rf):.2f}")
print(confusion_matrix(y_test, y_pred_best_rf))
print(classification_report(y_test, y_pred_best_rf))
# Out:
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# Best Parameters: {'max_depth': 20, 'min_samples_split': 2, 'n_estimators': 200}
# Best Random Forest Results:
# Accuracy: 0.97
# [[ 1  1]
#  [ 1 59]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50         2
#            1       0.98      0.98      0.98        60
#
#     accuracy                           0.97        62
#    macro avg       0.74      0.74      0.74        62
# weighted avg       0.97      0.97      0.97        62

# %% [markdown]
# MODEL INTERPRETATION (FEATURE IMPORTANCE FOR RANDOM FOREST)

# %% [markdown]
# You can visualize which features were most important in the model’s decision-making:

# %%
# Plot feature importances from Random Forest
features = X.columns
importances = best_rf.feature_importances_
indices = np.argsort(importances)

plt.figure(figsize=(10, 6))
plt.title("Feature Importances")
plt.barh(range(len(indices)), importances[indices], align="center")
plt.yticks(range(len(indices)), features[indices])
plt.xlabel("Relative Importance")
plt.show()

# %% [markdown]
# MODEL DEPLOYMENT

# %% [markdown]
# Once you are satisfied with the model, you can save it and deploy it using joblib:

# %%
import joblib

# Save the trained model
joblib.dump(best_rf, 'lung_cancer_model.pkl')

# To load and use the model later:
loaded_model = joblib.load('lung_cancer_model.pkl')

# Predict and display a meaningful result
sample_data = np.array([X_test[0]])  # Use a sample from your test set
prediction = loaded_model.predict(sample_data)

if prediction[0] == 1:
    print("The model predicts: Lung Cancer")
else:
    print("The model predicts: No Lung Cancer")
# Out:
# The model predicts: Lung Cancer
